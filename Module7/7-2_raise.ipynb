# %%
# 自訂例外處理
x = -1

if not x > 0:
    raise ValueError("x要大於0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       1 # 自訂例外處理
#       2 x = -1
#       3
#       4 if not x > 0:
# ----> 5     raise ValueError("x要大於0")
#
# ValueError: x要大於0

# %%
# 自訂型別錯誤(TypeError)的例外處理
file = "xxx.txt"

# 取後面三個字
if file[-3:].lower != "pdf":
    raise TypeError("副檔名有誤，一定要是.pdf")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 file = "xxx.txt"
#       3
#       4 # 取後面三個字
#       5 if file[-3:].lower != "pdf":
# ----> 6     raise TypeError("副檔名有誤，一定要是.pdf")
#
# TypeError: 副檔名有誤，一定要是.pdf

# %% [markdown]
# ##### 設計 raise 陳述
